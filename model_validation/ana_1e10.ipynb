# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# /home/zhonghua/Filt_Event/recE/combined_E1e10_M_params.csv
df=pd.read_csv("/home/zhonghua/Filt_Event/recE/combined_E1e10_M_params.csv")
df['r']=np.sqrt(df['rec_x']**2+df['rec_y']**2)
# df_NpE3=df[(df["NpE3"]>80)]
df_r=df[(df["r"]<550) & (df["r"]>250)]
print(len(df_r)/len(df))
# plt.hist(df['r'],bins=100)
# plt.show()
plt.hist(df_r['Eage'],bins=100)
plt.hist(df['Eage'],bins=100,alpha=0.5)
plt.yscale('log')
plt.show()

plt.hist(df_r['R_ue'], bins=100, alpha=0.5)
plt.hist(df['R_ue'], bins=100, alpha=0.5)
plt.yscale('log')
plt.show()

num_df=len(df[(df["R_ue"]<-3.2)])
num_df_r=len(df_r[(df_r["R_ue"]<-3.2)])
print(num_df_r/num_df)
# Out:
# 0.6996687958362905
# 0.6306769494430163
